# %%
import pandas as pd
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %%
####### JS Framework Tag Dataframe Load ##########
df = pd.read_csv('js-framework-tags-dataframe.csv')
df
# Out:
#        Unnamed: 0 framework                     creation_date
# 0               0   angular  2014-09-04 16:52:46.773000+00:00
# 1               1     react  2020-09-01 20:03:31.093000+00:00
# 2               2    jquery  2013-03-18 10:35:23.560000+00:00
# 3               3    jquery  2015-03-21 18:25:26.177000+00:00
# 4               4   angular  2015-06-19 11:35:54.500000+00:00
# ...           ...       ...                               ...
# 19995       19995   angular  2018-06-21 14:33:08.267000+00:00
# 19996       19996    jquery  2013-10-27 18:26:06.710000+00:00
# 19997       19997     react  2020-07-06 15:36:16.493000+00:00
# 19998       19998    jquery  2011-06-01 16:16:19.287000+00:00
# 19999       19999   angular  2014-06-25 15:41:17.557000+00:00
#
# [20000 rows x 3 columns]

# %%
######### Elaborate counts #####################
def creationDateToDay(date):
    return pd.to_datetime(date).to_period('M')


df['month'] = df['creation_date'].map(creationDateToDay)
# Out:
# <ipython-input-4-59946d71befd>:3: UserWarning: Converting to Period representation will drop timezone information.
#   return pd.to_datetime(date).to_period('M')

# %%
tab = df.groupby(["month", "framework"]).size().unstack(fill_value=0)
tab
# Out:
# framework  angular  ember.js  jquery  react  svelte  vue.js
# month
# 2008-09          0         0       1      0       0       0
# 2008-10          0         0       2      0       0       0
# 2008-11          0         0       1      0       0       0
# 2008-12          0         0       4      0       0       0
# 2009-01          0         0       3      0       0       0
# ...            ...       ...     ...    ...     ...     ...
# 2020-05         73         1      44    130       0      28
# 2020-06         63         1      42    115       1      27
# 2020-07         55         0      40    117       0      19
# 2020-08         43         1      44    135       2      15
# 2020-09         11         0       4     17       0       3
#
# [145 rows x 6 columns]

# %%
px.line(x=tab.index.to_timestamp(), y=tab.angular)

# fe6039
# 8e44ab
# af7b40

fig = go.Figure()
fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab.angular, mode='lines', name="Angular", 
              line=dict(color='#e74c3c', width=2)))
fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab.react, mode='lines', name="React", 
              line=dict(color='#74b9ff', width=2)))
fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab["vue.js"], mode='lines', name="Vue.js", 
              line=dict(color='#1abc9c', width=2)))

fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab["ember.js"], mode='lines', name="Ember.js", 
              line=dict(color='#8e44ab', width=2)))
fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab["svelte"], mode='lines', name="Svelte", 
              line=dict(color='#af7b40', width=2)))
fig.add_trace(go.Scatter(x=tab.index.to_timestamp(), y=tab["jquery"], mode='lines', name="jQuery", 
              line=dict(color='#8e44ab', width=2)))

fig.update_layout(title='Frontend framework interest over the years 2008-2020 (based on a 20k sample)',
                   xaxis_title='Years',
                   yaxis_title='Number of questions (sample relative)')

fig.show()
# Out:
# <div>                            <div id="a98f9872-85c6-4be1-ad43-a8a166cf91bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a98f9872-85c6-4be1-ad43-a8a166cf91bf")) {                    Plotly.newPlot(                        "a98f9872-85c6-4be1-ad43-a8a166cf91bf",                        [{"line": {"color": "#e74c3c", "width": 2}, "mode": "lines", "name": "Angular", "type": "scatter", "x": ["2008-09-01T00:00:00", "2008-10-01T00:00:00", "2008-11-01T00:00:00", "2008-12-01T00:00:00", "2009-01-01T00:00:00", "2009-02-01T00:00:00", "2009-03-01T00:00:00", "2009-04-01T00:00:00", "2009-05-01T00:00:00", "2009-06-01T00:00:00", "2009-07-01T00:00:00", "2009-08-01T00:00:00", "2009-09-01T00:00:00", "2009-10-01T00:00:00", "2009-11-01T00:00:00", "2009-12-01T00:00:
# ...

# %%
##PROBLEMA QUI##

df['count'] = 1
df = df.groupby(['creation_date', 'framework']).count().unstack()
df

# %%
######### Display JS Framework Line Chart #############
chart = px.line(df, x='creation_date', color='framework')
chart.show()

# %%
yearMask = df['creation_date']==2019

yearDf = df[yearMask]['framework']

hist = px.histogram(yearDf, title="JS Framework Interest in 2019 (based on 2k sample)")
hist.show()

yearMask = df['creation_date']==2018

yearDf = df[yearMask]['tags']

hist = px.histogram(yearDf, title="JS Framework Interest in 2018 (based on 2k sample)")
hist.show()

yearMask = df['creation_date']==2017

yearDf = df[yearMask]['framework']

hist = px.histogram(yearDf, title="JS Framework Interest in 2017 (based on 2k sample)")
hist.show()
