# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
####### JS Framework Tag Dataframe Load ##########
df = pd.read_csv('js-framework-tags-dataframe.csv')
df = df.drop(columns=['id'])
df
# Out:
#       framework                     creation_date
# 0       angular  2018-12-13 13:34:33.387000+00:00
# 1       angular  2015-02-05 16:49:21.420000+00:00
# 2       angular  2016-03-03 10:45:13.417000+00:00
# 3       angular  2014-11-21 12:53:33.067000+00:00
# 4       angular  2016-10-06 18:33:56.357000+00:00
# ...         ...                               ...
# 19995   angular  2018-05-22 16:55:20.140000+00:00
# 19996   angular  2017-11-24 16:09:47.427000+00:00
# 19997   angular  2016-07-10 08:18:32.437000+00:00
# 19998   angular  2017-09-27 15:58:32.067000+00:00
# 19999   angular  2016-03-18 16:28:10.103000+00:00
#
# [20000 rows x 2 columns]

# %%
######### Elaborate counts #####################
def creationDateToDay(date):
    return pd.to_datetime(date).to_period('M')


df['creation_date'] = df['creation_date'].map(creationDateToDay)
# Out:
# <ipython-input-78-b51a9257d350>:3: UserWarning:
#
# Converting to Period representation will drop timezone information.

# %%
##PROBLEMA QUI##

df['count'] = 1
df = df.groupby(['creation_date', 'framework']).count().unstack()
df
# Out:
#                 count
# framework     angular  react vue.js
# creation_date
# 2009-07           NaN    1.0    NaN
# 2009-10           1.0    NaN    NaN
# 2009-12           NaN    1.0    NaN
# 2010-01           NaN    1.0    NaN
# 2010-08           NaN    1.0    NaN
# ...               ...    ...    ...
# 2020-05         151.0  295.0   57.0
# 2020-06         151.0  266.0   53.0
# 2020-07         146.0  278.0   47.0
# 2020-08         112.0  295.0   48.0
# 2020-09          16.0   58.0    6.0
#
# [117 rows x 3 columns]

# %%
######### Display JS Framework Line Chart #############
chart = px.line(df, x='creation_date', color='framework')
chart.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-ddc0021f15a2> in <module>
#       1 ######### Display JS Framework Line Chart #############
# ----> 2 chart = px.line(df, x='creation_date', color='framework')
#       3 chart.show()
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     250     a polyline mark in 2D space.
#     251     """
# --> 252     return make_figure(args=locals(), constructor=go.Scatter)
#     253
#     254
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1824     apply_default_cascade(args)
#    1825
# -> 1826     args = build_dataframe(args, constructor)
#    1827     if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1828         args = process_dataframe_hierarchy(args)
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1356     # now that things have been prepped, we do the systematic rewriting of `args`
#    1357
# -> 1358     df_output, wide_id_vars = process_args_into_dataframe(
#    1359         args, wide_mode, var_name, value_name
#    1360     )
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1162                         if argument == "index":
#    1163                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1164                         raise ValueError(err_msg)
#    1165                 elif length and len(df_input[argument]) != length:
#    1166                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of [('count', 'angular'), ('count', 'react'), ('count', 'vue.js')] but received: creation_date

# %%
yearMask = df['creation_date']==2019

yearDf = df[yearMask]['framework']

hist = px.histogram(yearDf, title="JS Framework Interest in 2019 (based on 2k sample)")
hist.show()

yearMask = df['creation_date']==2018

yearDf = df[yearMask]['tags']

hist = px.histogram(yearDf, title="JS Framework Interest in 2018 (based on 2k sample)")
hist.show()

yearMask = df['creation_date']==2017

yearDf = df[yearMask]['framework']

hist = px.histogram(yearDf, title="JS Framework Interest in 2017 (based on 2k sample)")
hist.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d6244437a839> in <module>
#       3 yearDf = df[yearMask]['framework']
#       4
# ----> 5 hist = px.histogram(yearDf, title="JS Framework Interest in 2019 (based on 2k sample)")
#       6 hist.show()
#       7
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, title, template, width, height)
#     448     `orientation` is `'h'`).
#     449     """
# --> 450     return make_figure(
#     451         args=locals(),
#     452         constructor=go.Histogram,
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1852                 prefix = get_label(args, args["facet_row"]) + "="
#    1853                 row_labels = [prefix + str(s) for s in sorted_group_values[m.grouper]]
# -> 1854             for val in sorted_group_values[m.grouper]:
#    1855                 if val not in m.val_map:
#    1856                     m.val_map[val] = m.sequence[len(m.val_map) % len(m.sequence)]
#
# KeyError: 'variable'
